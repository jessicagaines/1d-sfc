# %%
from run_pitch_model import demo

# %% [markdown]
# ![title](img/model_diagram.png)
# ###### Gaines JL, Kim KS, Parrell B, Ramanarayanan V, Pongos AL, Nagarajan SS, et al. (2024) Bayesian inference of state feedback control parameters for fo perturbation responses in cerebellar ataxia. PLoS Comput Biol 20(10): e1011986. https://doi.org/10.1371/journal.pcbi.1011986

# %%
auditory_delay = 102.7 #ms
somatosensory_delay = 35.3 #ms
feedback_noise_cov = -5.8 #log scale
feedback_noise_ratio = 2.0 #aud:somat noise covariance
controller_gain = 1.9

tunable_parameters = [auditory_delay, somatosensory_delay, feedback_noise_cov, feedback_noise_ratio, controller_gain]
demo('pitch_pert_configs.ini',tunable_parameters)
